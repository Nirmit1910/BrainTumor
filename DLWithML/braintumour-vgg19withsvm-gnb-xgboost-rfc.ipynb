png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_538.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_999.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_122.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_152.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_959.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_58.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_1343.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_809.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_154.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_117.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_1007.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_1086.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_980.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_153.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_1100.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_417.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_800.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_1124.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_260.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_1197.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_1298.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_913.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_249.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_1142.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_1082.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_278.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_634.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_1119.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_1011.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_407.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_766.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_348.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_198.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_1113.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_203.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_354.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_1231.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_1270.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_921.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_1404.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_810.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_474.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_84.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_1162.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_577.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_1352.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_543.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_492.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_582.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_889.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_1350.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_300.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_1096.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_1154.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_1315.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_507.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_419.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_1235.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_1321.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_450.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_1085.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_1139.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_44.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_852.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_420.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_778.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_93.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_362.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_655.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_358.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_454.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_1377.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_847.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_282.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_1312.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_387.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_178.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_856.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_274.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_429.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_171.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_839.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_200.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_1426.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_613.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_969.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_642.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_977.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_440.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_979.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_1133.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_937.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_606.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_703.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_352.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_266.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_1281.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_704.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_1358.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_131.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_514.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_970.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_109.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_1207.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_479.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_1322.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_65.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_964.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_728.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_685.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_850.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_20.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_435.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_246.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_848.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_365.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_943.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_1363.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_334.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_229.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_832.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_759.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_6.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_1221.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_467.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_477.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_437.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_313.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_468.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_1136.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_481.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_1170.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_557.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_1155.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_1003.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_333.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_112.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_983.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_194.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_931.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_643.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_678.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_1304.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_1351.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_849.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_376.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_1309.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_1117.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_1049.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_1245.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_647.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_749.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_1416.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_398.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_650.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_840.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_1320.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_1008.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_967.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_1156.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_1091.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_652.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_2.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_1271.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_630.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_858.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_583.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_570.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_1166.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_594.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_1256.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_1125.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_306.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_259.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_157.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_718.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_68.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_60.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_934.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_935.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_1065.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_752.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_243.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_533.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_944.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_712.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_851.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_1022.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_394.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_293.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_1121.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_378.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_251.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_1045.png
# /kaggle/input/mridataset/cleaned/Testing/Glioma/image1_1101.png

# %% [markdown]
# # Importing necessary libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import skimage.io
import os 
import tqdm
import glob
import tensorflow 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import tensorflow as tf
from tensorflow.keras.utils import image_dataset_from_directory
from tensorflow.data.experimental import AUTOTUNE
from tensorflow.keras import Sequential, Input, Model
from tensorflow.keras.layers import RandomRotation, RandomZoom
from tensorflow.keras.layers.experimental.preprocessing import Rescaling
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras import applications
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.optimizers import Adam


from tqdm import tqdm
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from skimage.io import imread, imshow
from skimage.transform import resize

from tensorflow.keras.models import Sequential
from tensorflow.keras.metrics import Precision, AUC,Recall
from tensorflow.keras.layers import InputLayer, BatchNormalization, Dropout, Flatten, Dense, Activation, MaxPool2D, Conv2D
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.applications.densenet import DenseNet169
import copy
import warnings
warnings.filterwarnings('ignore')
import tensorflow as tf
import cv2
import keras
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import load_img, img_to_array
import matplotlib
import matplotlib.pylab as plt
import seaborn as sns
from sklearn.utils import shuffle
from sklearn.metrics import confusion_matrix
from tensorflow.keras.applications.resnet import preprocess_input
from tensorflow.keras.applications import InceptionResNetV2
from tensorflow.keras.utils import image_dataset_from_directory

# %%
train_dir = '/kaggle/input/mridataset/cleaned/Training/'
test_dir = '/kaggle/input/mridataset/cleaned/Testing/'

train_paths = []
train_labels = []

for label in os.listdir(train_dir):
    for image in os.listdir(train_dir+label):
        train_paths.append(train_dir+label+'/'+image)
        train_labels.append(label)

train_paths, train_labels = shuffle(train_paths, train_labels)

# %%
test_paths = []
test_labels = []

for label in os.listdir(test_dir):
    for image in os.listdir(test_dir+label):
        test_paths.append(test_dir+label+'/'+image)
        test_labels.append(label)

test_paths, test_labels = shuffle(test_paths, test_labels)

# %% [markdown]
# # Visualizing class distribution

# %%
import matplotlib.pyplot as plt

# Data
labels = ['Pituitary', 'Meningioma', 'Glioma']
sizes = [
    len([x for x in train_labels if x == 'Pituitary']),
    len([x for x in train_labels if x == 'Meningioma']),
    len([x for x in train_labels if x == 'Glioma'])
]

# Custom color palette for a brain tumor vibe
colors = ['#D4A5A5', '#D1C0E0', '#B8D8D8']
explode = (0.015, 0.015, 0.015)

# Plotting
plt.figure(figsize=(10, 6))
plt.pie(sizes, labels=labels, colors=colors, autopct='%.1f%%', explode=explode, startangle=30, wedgeprops=dict(width=0.2))

# Title
plt.title('Distribution of Tumor Types', fontsize=20)

# Add a legend
plt.legend(labels, title='Tumor Types', loc='upper right', bbox_to_anchor=(1, 0, 0.5, 1))

# Equal aspect ratio ensures that pie is drawn as a circle.
plt.axis('equal')

# Show the plot
plt.show()

# %% [markdown]
# # Distribution of Data between Train and Test Sets

# %%
import matplotlib.pyplot as plt

# Data
labels = ['Train', 'Test']
sizes = [len(train_labels), len(test_labels)]
colors = ['#BEF0CB', '#C1AEFC']
explode = (0.05, 0)

# Plotting
plt.figure(figsize=(6, 4))
plt.pie(sizes, labels=labels, colors=colors, autopct='%.1f%%', explode=explode, startangle=30, wedgeprops=dict(width=0.2))

# Title
plt.title('Distribution of Data between Train and Test Sets', fontsize=20)

# Equal aspect ratio ensures that pie is drawn as a circle.
plt.axis('equal')


# Show the plot
plt.show()

# %% [markdown]
# # Count of each class

# %%
plt.figure(figsize=(10,4))
colors = ['#FF6347',  # Red for glioma
          '#4169E1',  # Blue for meningioma
          '#FFA500']  # Orange for pituitary
plt.bar(['glioma','meningioma','pituitary'],[1140,566,744],color=colors)

plt.xlabel('Classes')
plt.ylabel('Counts')
plt.title('Visualization of Data')
plt.gca().set_facecolor('#F5F5F5')
plt.show()

# %%
def train_df(tr_path):
    classes = []
    class_paths = []
    files = os.listdir(tr_path)
    for file in files:
        label_dir = os.path.join(tr_path, file)
        label = os.listdir(label_dir)
        for image in label:
            image_path = os.path.join(label_dir, image)
            class_paths.append(image_path)
            classes.append(file)
    image_classes = pd.Series(classes, name='Class')
    image_paths = pd.Series(class_paths, name='Class Path')
    tr_df = pd.concat([image_paths, image_classes], axis=1)
    return tr_df

# %%
def test_df(ts_path):
    classes = []
    class_paths = []
    files = os.listdir(ts_path)
    for file in files:
        label_dir = os.path.join(ts_path, file)
        label = os.listdir(label_dir)
        for image in label:
            image_path = os.path.join(label_dir, image)
            class_paths.append(image_path)
            classes.append(file)
    image_classes = pd.Series(classes, name='Class')
    image_paths = pd.Series(class_paths, name='Class Path')
    ts_df = pd.concat([image_paths, image_classes], axis=1)
    return ts_df

# %%
tr_df = train_df('/kaggle/input/mridataset/cleaned/Training')

# %%
ts_df = test_df('/kaggle/input/mridataset/cleaned/Testing')

# %%
tr_df.shape+ts_df.shape
# Out:
# (2450, 2, 614, 2)

# %% [markdown]
# # Creating validation dataset

# %%
train_df,valid_df = train_test_split(tr_df, train_size=.8, random_state=20)

# %% [markdown]
# # Data generators for Image Augmentation

# %%
image_size = (256, 256)

# Training batch size
batch_size = 32

SEED=1345

train_datagen=ImageDataGenerator(rescale=1./255,
                                   rotation_range=10,
                                   brightness_range=(0.85, 1.15),
                                   width_shift_range=0.002,
                                   height_shift_range=0.002,
                                   shear_range=12.5,
                                   zoom_range=0,
                                   horizontal_flip=True,
                                   vertical_flip=False,
                                   fill_mode="nearest")
validation_datagen=ImageDataGenerator(rescale=1./255)
test_datagen=ImageDataGenerator(rescale=1./255)


tr_gen = train_datagen.flow_from_dataframe(train_df, x_col='Class Path',
                                 y_col='Class',
                                 target_size=image_size,seed = SEED,
                                 batch_size=32,
                                 class_mode ='categorical',)

valid_gen = validation_datagen.flow_from_dataframe(valid_df, x_col='Class Path',
                                    y_col='Class',
                                    target_size=image_size,seed = SEED,
                                    batch_size=64,
                                    class_mode ='categorical',)

ts_gen = test_datagen.flow_from_dataframe(ts_df, x_col='Class Path',
                                y_col='Class',
                                 target_size=image_size,shuffle=False,
                                 seed = SEED,
                                 batch_size=32,
                                 class_mode ='categorical',)
# Out:
# Found 1960 validated image filenames belonging to 3 classes.
# Found 490 validated image filenames belonging to 3 classes.
# Found 614 validated image filenames belonging to 3 classes.

# %% [markdown]
# # Visualizing Data

# %%
class_names=list(tr_gen.class_indices.keys())

# %%
class_names
# Out:
# ['Glioma', 'Meningioma', 'Pituitary']

# %%
plt.figure(figsize=(5, 5))
for images, labels in tr_gen:
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i])
        plt.title(class_names[np.argmax(labels[i])])
        plt.axis("off")
    break

# %% [markdown]
# # Model Creation VGG19

# %%
input_shape = (256, 256, 3)

# Create an instance of the VGG19 model
vgg19 = keras.applications.VGG19(include_top=False, input_shape=input_shape,
                   weights='imagenet')

train_features = vgg19.predict(tr_gen, steps=len(tr_gen), verbose=1)
val_features=vgg19.predict(valid_gen,len(valid_gen),verbose=1)
test_features = vgg19.predict(ts_gen, steps=len(ts_gen), verbose=1)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 [==============================] - 4s 0us/step
# 62/62 [==============================] - 47s 694ms/step
# 8/8 [==============================] - 12s 902ms/step
# 20/20 [==============================] - 6s 308ms/step

# %%
train_labels=tr_gen.classes
val_labels=valid_gen.classes
test_label=ts_gen.classes

# %%
trainval_features = np.concatenate((train_features, val_features))
trainval_labels = np.concatenate((train_labels, val_labels))

# %%
X_train_2d = trainval_features.reshape(trainval_features.shape[0], -1)

# %%
X_test_2d = test_features.reshape(test_features.shape[0], -1)

# %% [markdown]
# # PCA

# %%
from sklearn.pipeline import Pipeline
from sklearn.decomposition import PCA
pca = PCA()

# %%
X_pca = pca.fit_transform(X_train_2d)

# %%
#Determine the number of components
explained_variance_ratio = pca.explained_variance_ratio_
cumulative_explained_variance_ratio = np.cumsum(explained_variance_ratio)

# %%
# Plot the cumulative explained variance ratio
import matplotlib.pyplot as plt
plt.plot(range(1, len(cumulative_explained_variance_ratio) + 1), cumulative_explained_variance_ratio)
plt.xlabel('Number of Components')
plt.ylabel('Cumulative Explained Variance Ratio')
plt.grid(True)
plt.show()

# %%
# Choose the number of components that capture a significant portion of variance (90%)
n_components = np.argmax(cumulative_explained_variance_ratio >= 0.9) + 1
selected_features = X_pca[:, :n_components]

# %%
selected_features.shape
# Out:
# (2450, 1)

# %%
X_train=selected_features

# %%
indices = np.random.permutation(2450)

# Shuffle X_train and X_labels using the same indices
shuffled_X_train = X_train[indices]
shuffled_X_labels = trainval_labels[indices]

# %%
indices
# Out:
# array([2071,  995, 1049, ..., 1625, 1754,  171])

# %% [markdown]
# # XGB

# %%
import xgboost as xgb
xgb = xgb.XGBClassifier(n_estimators=150,max_depth=5,learning_rate=0.01)
xgb.fit(shuffled_X_train, shuffled_X_labels)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.01, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=5, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=150, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softprob', ...)

# %%
X_test=pca.transform(X_test_2d)
X_test=X_test[:, :n_components]
xgb.score(X_test,test_label)
# Out:
# 0.4723127035830619

# %%
from sklearn.metrics import confusion_matrix, classification_report
# Make predictions on the test data
y_pred = xgb.predict(X_test)

# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_confusion_matrix(cm, classes, normalize=False, cmap=plt.cm.Blues):
    if normalize:
#         cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        title = "Normalized Confusion Matrix"
    else:
        title = "Confusion Matrix"

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=90)
    plt.yticks(tick_marks, classes)

    fmt = 'd'
#     '.2f' if normalize else 
    thresh = cm.max() / 2.
    for i, j in np.ndindex(cm.shape):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

cm = confusion_matrix(test_label, y_pred)

class_names

plt.figure(figsize=(8, 6))
plot_confusion_matrix(cm, class_names, normalize=True)
plt.show()

# %%
# Compute the classification report
report = classification_report(test_label, y_pred)
print("Classification Report:")
print(report)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.47      0.97      0.63       286
#            1       0.60      0.02      0.04       142
#            2       0.47      0.05      0.09       186
#
#     accuracy                           0.47       614
#    macro avg       0.51      0.35      0.25       614
# weighted avg       0.50      0.47      0.33       614

# %% [markdown]
# # GaussianNaiveBayes

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
gnb.fit(shuffled_X_train, shuffled_X_labels)
# Out:
# GaussianNB()

# %%
gnb.score(X_test,test_label)
# Out:
# 0.23127035830618892

# %%
y_pred = gnb.predict(X_test)

# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_confusion_matrix(cm, classes, normalize=False, cmap=plt.cm.Blues):
    if normalize:
#         cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        title = "Normalized Confusion Matrix"
    else:
        title = "Confusion Matrix"

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=90)
    plt.yticks(tick_marks, classes)

    fmt = 'd'
#     '.2f' if normalize else 
    thresh = cm.max() / 2.
    for i, j in np.ndindex(cm.shape):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

cm = confusion_matrix(test_label, y_pred)

class_names

plt.figure(figsize=(8, 6))
plot_confusion_matrix(cm, class_names, normalize=True)
plt.show()

# %%
# Compute the classification report
report = classification_report(test_label, y_pred)
print("Classification Report:")
print(report)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       286
#            1       0.23      1.00      0.38       142
#            2       0.00      0.00      0.00       186
#
#     accuracy                           0.23       614
#    macro avg       0.08      0.33      0.13       614
# weighted avg       0.05      0.23      0.09       614

# %% [markdown]
# # SVC

# %%
from sklearn.svm import SVC

# %%
svc = SVC()
svc.fit(shuffled_X_train, shuffled_X_labels)
# Out:
# SVC()

# %%
svc.score(X_test,test_label)
# Out:
# 0.46416938110749184

# %%
y_pred = svc.predict(X_test)

# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_confusion_matrix(cm, classes, normalize=False, cmap=plt.cm.Blues):
    if normalize:
#         cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        title = "Normalized Confusion Matrix"
    else:
        title = "Confusion Matrix"

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=90)
    plt.yticks(tick_marks, classes)

    fmt = 'd'
#     '.2f' if normalize else 
    thresh = cm.max() / 2.
    for i, j in np.ndindex(cm.shape):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

cm = confusion_matrix(test_label, y_pred)

class_names

plt.figure(figsize=(8, 6))
plot_confusion_matrix(cm, class_names, normalize=True)
plt.show()

# %%
# Compute the classification report
report = classification_report(test_label, y_pred)
print("Classification Report:")
print(report)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.46      1.00      0.63       286
#            1       0.00      0.00      0.00       142
#            2       0.00      0.00      0.00       186
#
#     accuracy                           0.46       614
#    macro avg       0.15      0.33      0.21       614
# weighted avg       0.22      0.46      0.30       614

# %% [markdown]
# # Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier()

# %%
grid_space={'max_depth':[3,5,10,None],
              'n_estimators':[10,100,200],
              'max_features':[1,3,5,7],
              'min_samples_leaf':[1,2,3],
              'min_samples_split':[1,2,3]
           }

# %%
from sklearn.model_selection import GridSearchCV

grid = GridSearchCV(rf,param_grid=grid_space,cv=3,scoring='accuracy')
model_grid = grid.fit(shuffled_X_train, shuffled_X_labels)

# %%
print('Best hyperparameters are: '+str(model_grid.best_params_))
print('Best score is: '+str(model_grid.best_score_))
# Out:
# Best hyperparameters are: {'max_depth': 3, 'max_features': 5, 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 10}
# Best score is: 0.46612227102183185

# %%
y_pred = svc.predict(X_test)

# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_confusion_matrix(cm, classes, normalize=False, cmap=plt.cm.Blues):
    if normalize:
#         cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        title = "Normalized Confusion Matrix"
    else:
        title = "Confusion Matrix"

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=90)
    plt.yticks(tick_marks, classes)

    fmt = 'd'
#     '.2f' if normalize else 
    thresh = cm.max() / 2.
    for i, j in np.ndindex(cm.shape):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

cm = confusion_matrix(test_label, y_pred)

class_names

plt.figure(figsize=(8, 6))
plot_confusion_matrix(cm, class_names, normalize=True)
plt.show()

# %%
# Compute the classification report
report = classification_report(test_label, y_pred)
print("Classification Report:")
print(report)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.46      1.00      0.63       286
#            1       0.00      0.00      0.00       142
#            2       0.00      0.00      0.00       186
#
#     accuracy                           0.46       614
#    macro avg       0.15      0.33      0.21       614
# weighted avg       0.22      0.46      0.30       614
